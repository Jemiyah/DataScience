# %%
import pandas as pd
import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam, SGD, RMSprop
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from scikeras.wrappers import KerasClassifier
from functools import partial
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("Alphabets_data.csv")
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19998      S     2     3      4       2      1     8     7      2      6
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0          6      10       8      0       8      0       8
# 1         13       3       9      2       8      4      10
# 2         10       3       7      3       7      3       9
# 3          4       4      10      6      10      2       8
# 4          6       5       9      1       7      5      10
# ...      ...     ...     ...    ...     ...    ...     ...
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19998     10       6       8      1       9      5       8
# 19999      8       1       8      2       7      2       8
#
# [20000 rows x 17 columns]

# %%
# Data Exploration

# %%
df.isna().any()
# Out:
# letter    False
# xbox      False
# ybox      False
# width     False
# height    False
# onpix     False
# xbar      False
# ybar      False
# x2bar     False
# y2bar     False
# xybar     False
# x2ybar    False
# xy2bar    False
# xedge     False
# xedgey    False
# yedge     False
# yedgex    False
# dtype: bool

# %%
df.isnull().any()
# Out:
# letter    False
# xbox      False
# ybox      False
# width     False
# height    False
# onpix     False
# xbar      False
# ybar      False
# x2bar     False
# y2bar     False
# xybar     False
# x2ybar    False
# xy2bar    False
# xedge     False
# xedgey    False
# yedge     False
# yedgex    False
# dtype: bool

# %%
df.duplicated().any()
# Out:
# True

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       letter  xbox  ybox  width  height  onpix  xbar  ybar  x2bar  y2bar  \
# 0          T     2     8      3       5      1     8    13      0      6
# 1          I     5    12      3       7      2    10     5      5      4
# 2          D     4    11      6       8      6    10     6      2      6
# 3          N     7    11      6       6      3     5     9      4      6
# 4          G     2     1      3       1      1     8     6      6      6
# ...      ...   ...   ...    ...     ...    ...   ...   ...    ...    ...
# 19994      T     5     8      7       7      7     7     9      4      8
# 19995      D     2     2      3       3      2     7     7      7      6
# 19996      C     7    10      8       8      4     4     8      6      9
# 19997      T     6     9      6       7      5     6    11      3      7
# 19999      A     4     9      6       6      2     9     5      3      1
#
#        xybar  x2ybar  xy2bar  xedge  xedgey  yedge  yedgex
# 0          6      10       8      0       8      0       8
# 1         13       3       9      2       8      4      10
# 2         10       3       7      3       7      3       9
# 3          4       4      10      6      10      2       8
# 4          6       5       9      1       7      5      10
# ...      ...     ...     ...    ...     ...    ...     ...
# 19994      7       7       8      3      10      8       6
# 19995      6       6       4      2       8      3       7
# 19996     12       9      13      2       9      3       7
# 19997     11       9       5      2      12      2       4
# 19999      8       1       8      2       7      2       8
#
# [18668 rows x 17 columns]

# %%
# Encoding labels

# %%
label_encoder = LabelEncoder()
df['letter'] = label_encoder.fit_transform(df['letter'])

# %%
# Splitting features and labels

# %%
X = df.drop(columns=['letter'])
y = df['letter']

# %%
# Standardization

# %%
scaler = StandardScaler()
scaler.fit(X)
X_standardized = scaler.transform(X)

# %%
# Splitting dataset into training and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X_standardized, y, test_size=0.2, random_state=42)

# %%
# Function to create model

# %%
def create_model(learning_rate=0.001, neurons=32, activation='relu', optimizer='adam', dropout_rate=0.2):
    model = Sequential([
        Dense(neurons, activation=activation, input_shape=(X_train.shape[1],)),
        Dropout(dropout_rate),
        Dense(neurons, activation=activation),
        Dropout(dropout_rate),
        Dense(len(np.unique(y)), activation='softmax')
    ])
    
    if optimizer == 'adam':
        opt = Adam(learning_rate=learning_rate)
    elif optimizer == 'sgd':
        opt = SGD(learning_rate=learning_rate)
    elif optimizer == 'rmsprop':
        opt = RMSprop(learning_rate=learning_rate)
    else:
        opt = Adam(learning_rate=learning_rate)
    
    model.compile(optimizer=opt,
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
# Wrapping model with KerasClassifier

# %%
model = KerasClassifier(model=partial(create_model), verbose=0)

# %%
# Function to tune each hyperparameter separately

# %%
def tune_hyperparameter(param_grid):
    grid = GridSearchCV(estimator=model, param_grid=param_grid, cv=3, n_jobs=-1)
    grid_result = grid.fit(X_train, y_train)
    return grid_result.best_params_

# %%
best_learning_rate = tune_hyperparameter({'model__learning_rate': [0.001, 0.01, 0.1]})['model__learning_rate']
best_learning_rate
# Out:
# 0.01

# %%
best_neurons = tune_hyperparameter({'model__neurons': [32, 64, 128]})['model__neurons']
best_neurons
# Out:
# 128

# %%
best_activation = tune_hyperparameter({'model__activation': ['relu', 'tanh', 'sigmoid']})['model__activation']
best_activation
# Out:
# 'tanh'

# %%
best_optimizer = tune_hyperparameter({'model__optimizer': ['adam', 'sgd', 'rmsprop']})['model__optimizer']
best_optimizer
# Out:
# 'adam'

# %%
best_dropout = tune_hyperparameter({'model__dropout_rate': [0.2, 0.3, 0.4]})['model__dropout_rate']
best_dropout
# Out:
# 0.2

# %%
# Training the final model with best parameters

# %%
final_model = create_model(
    best_learning_rate, best_neurons, best_activation,
    best_optimizer, best_dropout
)

# %%
# Training with optimal batch size and epochs

# %%
final_model.fit(X_train, y_train, epochs=30, batch_size=32, verbose=1)
# Out:
# Epoch 1/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.5905 - loss: 1.3847
# Epoch 2/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7637 - loss: 0.7826
# Epoch 3/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.7904 - loss: 0.6873
# Epoch 4/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8073 - loss: 0.6534
# Epoch 5/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8097 - loss: 0.6454
# Epoch 6/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8261 - loss: 0.5831
# Epoch 7/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8250 - loss: 0.6106
# Epoch 8/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8292 - loss: 0.5871
# Epoch 9/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8382 - loss: 0.5607
# Epoch 10/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8448 - loss: 0.5315
# Epoch 11/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8419 - loss: 0.5613
# Epoch 12/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8392 - loss: 0.5578
# Epoch 13/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8457 - loss: 0.5336
# Epoch 14/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.8531 - loss: 0.5320
# Epoch 15/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8529 - loss: 0.5166
# Epoch 16/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8481 - loss: 0.5253
# Epoch 17/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8476 - loss: 0.5314
# Epoch 18/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8537 - loss: 0.5400
# Epoch 19/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8535 - loss: 0.5217
# Epoch 20/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8634 - loss: 0.4929
# Epoch 21/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8536 - loss: 0.5000
# Epoch 22/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8527 - loss: 0.5225
# Epoch 23/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8585 - loss: 0.5111
# Epoch 24/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8526 - loss: 0.5153
# Epoch 25/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8524 - loss: 0.5039
# Epoch 26/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8647 - loss: 0.4781
# Epoch 27/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8618 - loss: 0.4846
# Epoch 28/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8595 - loss: 0.5265
# Epoch 29/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8638 - loss: 0.4839
# Epoch 30/30
# 467/467 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.8484 - loss: 0.5330

# %%
# Evaluation

# %%
y_pred = np.argmax(final_model.predict(X_test), axis=1)
accuracy = accuracy_score(y_test, y_pred)
print("Final Model Accuracy:", accuracy)
print("Classification Report:")
print(classification_report(y_test, y_pred))
# Out:
# 117/117 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# Final Model Accuracy: 0.9094804499196572
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97       144
#            1       0.87      0.83      0.85       156
#            2       0.93      0.94      0.93       147
#            3       0.92      0.85      0.88       163
#            4       0.85      0.93      0.89       144
#            5       0.85      0.96      0.90       146
#            6       0.95      0.77      0.85       173
#            7       0.81      0.83      0.82       133
#            8       0.92      0.97      0.95       108
#            9       0.97      0.89      0.93       150
#           10       0.86      0.93      0.89       149
#           11       0.94      0.93      0.94       147
#           12       0.92      0.94      0.93       143
#           13       0.94      0.92      0.93       138
#           14       0.88      0.91      0.89       131
#           15       0.96      0.89      0.93       161
#           16       0.96      0.91      0.94       145
#           17       0.84      0.90      0.87       147
#           18       0.87      0.98      0.92       142
#           19       0.95      0.95      0.95       151
#           20       0.98      0.85      0.91       143
#           21       0.94      0.88      0.91       155
#           22       0.80      0.99      0.89       133
#           23       0.97      0.92      0.95       124
#           24       0.91      0.91      0.91       138
#           25       0.97      0.92      0.95       123
#
#     accuracy                           0.91      3734
#    macro avg       0.91      0.91      0.91      3734
# weighted avg       0.91      0.91      0.91      3734
